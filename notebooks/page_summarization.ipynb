# %%
import pandas as pd

selected_search_prompt = 2
selecred_extraction_prompt = 5

page_information = pd.read_csv('./data/page_information.csv')
page_information["query"] = page_information["query"].apply(lambda x: x.replace(" -cyberleninka -youtube -видео -pdf", ""))
queries = pd.read_csv('./data/web_search_results.csv')

queries = queries[queries["prompt"] == selected_search_prompt]
topics = pd.read_csv('./data/extraction_results.csv')
topics = topics[topics["prompt"] == selecred_extraction_prompt]

# %%
page_information['word_count'] = page_information["data"].apply(lambda x: len(x.split()) if isinstance(x, str) else 0)
page_information['word_count'].describe().astype(int)
# Out:
# count       480
# mean       1169
# std        6412
# min           3
# 25%         136
# 50%         633
# 75%        1148
# max      139150
# Name: word_count, dtype: int32

# %%
page_information[page_information["word_count"] < 15]
# Out:
#                                                  query  \
# 4          топ 5 упражнений для утренней зарядки видео
# 16   кейсы применения big data для оптимизации бизн...
# 17   как анализ больших данных повышает эффективнос...
# 24   методы развития критического мышления с упражн...
# 31   методы повышения продуктивности и организованн...
# ..                                                 ...
# 461  Влияние цифровых технологий на доступность обр...
# 463  Практические советы для снижения тревоги и упр...
# 466                    Как развить лидерские качества?
# 467   Методы развития лидерских качеств для начинающих
# 476                Как путешествия влияют на личность?
#
#                                                    url  \
# 4    https://alphamed.by/utrennyaya-zaryadka-kak-pr...
# 16   https://habr.com/ru/companies/newprolab/articl...
# 17      https://networking.camp/useful/advice/big-data
# 24   https://practicum.yandex.ru/blog/priemy-razvit...
# 31   https://sbercrm.com/blog/business/tpost/tkcjl9...
# ..                                                 ...
# 461  https://www.ppfsvfu.ru/jour/article/download/2...
# 463  https://gorzdrav.org/blog/kak-borotsja-so-stre...
# 466  https://www.sravni.ru/text/kak-razvit-v-sebe-l...
# 467  https://gershanovich.ru/blog/effektivnye-upraz...
# 476  https://today.travel/blog/blogs/kak-vliyaut-pu...
#
#                                                   data  word_count
# 4    {'error': 'Failed to retrieve the page. Status...           9
# 16   {'title': '7 кейсов использования технологий B...          14
# 17   {'error': 'Failed to retrieve the page. Status...           9
# 24   {'title': 'Ð\x92Ñ\x8b Ð½Ðµ Ñ\x80Ð¾Ð±Ð¾Ñ\x82?',...           6
# 31   {'title': 'Как повысить продуктивность работы ...          10
# ..                                                 ...         ...
# 461      {'title': 'No title found', 'paragraphs': []}           6
# 463      {'title': 'Access Blocked', 'paragraphs': []}           5
# 466  {'error': 'Failed to retrieve the page. Status...           9
# 467  {'error': 'Failed to retrieve the page. Status...           9
# 476  {'title': 'Как путешествия влияют на человека ...          10
#
# [88 rows x 4 columns]

# %%
import os

def get_models(directory, extension=".gguf"):
    return [filename.split(".")[0] for filename in os.listdir(directory) if filename.endswith(extension)]

models = get_models("../models")
print(models)
# Out:
# ['gemma-2-9b-it-Q8_0_L', 'saiga-llama-3-q8_0', 'suzume-llama-3-8b-Q8_0']

# %%
from langchain_community.llms import LlamaCpp
from langchain_community.chat_models import ChatOllama
from langchain_core.callbacks import CallbackManager, StreamingStdOutCallbackHandler


llama3_tokens = {
    'first_token': '<|begin_of_text|>',
    'start_header': '<|start_header_id|>', 
    'end_header': '<|end_header_id|>', 
    'end_message': '<|eot_id|>'
}
gemma2_tokens = {
    'first_token': '',
    'start_header': '<start_of_turn>',
    'end_header': '',
    'end_message': '<end_of_turn>'
}

def get_llm(path):

    model = LlamaCpp(
        model_path=path,
        temperature=0,
        n_ctx=8192,
        max_tokens=2000,
        top_p=1,
        repeat_penalty=1.1,
        # callback_manager=CallbackManager([StreamingStdOutCallbackHandler()]),
        verbose=False,
        n_gpu_layers=33
    )
    return model

def get_chat(model_name):
    chat = ChatOllama(model=model_name, temperature=0)
    return chat

# %%
summarization_prompt_base = """{first_token}{start_header}system{end_header}
Выдели из данного текста основные факты и данные, которые имеют наибольшую ценность и значимость. Особое внимание удели информации, касающейся темы: «{topic}», но не исключай другие важные факты и данные. Исключи общие фразы, лишние детали и несущественную информацию. 
Сформулируй результаты в виде краткого списка ключевых пунктов.

Текст:
{page}

Используй русский язык для формирования результатов.

{end_message}{start_header}assistant{end_header}\n"""

summarization_prompt_candidate_1 = """
Выдели из данного текста ключевые факты и данные, которые имеют наибольшую значимость. Особое внимание удели информации, касающейся темы: «{topic}», но не исключай другие важные факты и данные. Исключи общие фразы, повторяющуюся информацию и любые несущественные детали. 
Представь результаты в виде списка из коротких и информативных пунктов. Под ключевыми фактами подразумеваются даты, цифры, имена, места, конкретные события и статистические данные.

Текст:
{page}

Используй русский язык для формирования результатов.

{end_message}{start_header}assistant{end_header}\n"""

summarization_prompt_candidate_2 = """
Проанализируй данный текст и выдели из него ключевые факты и данные, которые имеют наибольшую значимость. Особое внимание удели информации, касающейся темы: «{topic}», но не исключай другие важные факты и данные. Исключи общие фразы, повторяющуюся информацию и любые несущественные детали. 
Представь результаты в виде списка из коротких и информативных пунктов. 

Под ключевыми фактами подразумеваются:
- Даты и временные промежутки
- Числовые данные и статистика
- Имена людей и организаций
- Названия мест
- Конкретные события и факты

Текст:
{page}

Используй русский язык для формирования результатов без дополнительных объяснений.

{end_message}{start_header}assistant{end_header}\n"""
summarization_candidates = [
    summarization_prompt_base,
    summarization_prompt_candidate_1,
    summarization_prompt_candidate_2
]

# %%
from langchain_core.output_parsers import JsonOutputParser, StrOutputParser
from langchain_core.prompts import PromptTemplate

import pandas as pd
import tqdm
from langchain_core.exceptions import OutputParserException


def get_summarization_prompt(prompt):
    summarization_prompt = PromptTemplate(
        template=prompt,
        input_variables=["first_token", "start_header", "end_header", "end_message", "thema", "page"],
    )
    return summarization_prompt

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

def get_len(text):
    return len(text.split())

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=50,
    length_function=get_len,
    is_separator_regex=False,
)

def split_chunk(chunk, max_words=1000):
    chunks = text_splitter.create_documents([chunk])
    return chunks

def combine_chunks(chunks, max_words=1000):
    combined_chunks = []
    current_chunk = ""

    for chunk in chunks:
        words_in_chunk = chunk.split()
        current_chunk_words = current_chunk.split()
        
        if len(current_chunk_words) + len(words_in_chunk) <= max_words:
            if current_chunk:
                current_chunk += " " + chunk
            else:
                current_chunk = chunk
        else:
            if current_chunk:
                combined_chunks.append(current_chunk)
            current_chunk = chunk
            
            if len(words_in_chunk) > max_words:
                split_chunks = split_chunk(chunk, max_words)
                combined_chunks.extend(split_chunks)
                current_chunk = ""
            else:
                current_chunk = chunk

    if current_chunk:
        combined_chunks.append(current_chunk)

    return combined_chunks

# %%
from langchain_core.output_parsers import StrOutputParser

num_message = 0
model = models[0]
input_dict = gemma2_tokens.copy() if "gemma" in model else llama3_tokens.copy()

topic = topics[(topics["num_message"] == num_message) & (topics["model"] == model)]["Тема"].iloc[0]

prompt = summarization_candidates[0]
summarization_prompt = get_summarization_prompt(prompt)
llm = get_chat(model)
summary_chain = summarization_prompt | llm | StrOutputParser()

# %% [markdown]
# # Invoke

# %%
def summarization(content):
    input_dict["topic"] = topic
    input_dict["page"] = content
    summary = summary_chain.invoke(input_dict)
    return summary

def page_summarization(page):
    page_chunks = page.get("paragraphs", None)
    
    chunks = combine_chunks([" ".join(chunk.split()) for chunk in page_chunks if len(chunk.split()) > 3], max_words=max_words)
    
    chunks_summaries = [summarization(chunk) for chunk in chunks]
    while len(chunks_summaries) > 1:
        chunks_summaries = [summarization(chunk) for chunk in combine_chunks(chunks_summaries, max_words=max_words)]
    return chunks_summaries[0]

def query_summarization(query_pages):
    query_pages = [eval(p) for p in query_pages]
    pages_summary = [page_summarization(page) for page in query_pages if page.get("paragraphs", None)]
    if len(pages_summary) > 1:
        summary = [summarization(chunk) for chunk in combine_chunks(pages_summary, max_words=max_words)]
        return summary
    return pages_summary[0]

# %%
# %%time

query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 500
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 297 ms
# Wall time: 2min 10s

# %%
# %%time
query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 1000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 93.8 ms
# Wall time: 1min 16s

# %%
print(s[0])
# Out:
# ## Ключевые факты и данные из текста:
#
# **Для увеличения количества прочитанных книг:**
#
# * Составьте wishread list с 8 темами развития и минимум 20 книгами в каждой, включая книги успешных людей.
# * Используйте психологический прием: представьте, что у вас осталось полгода жизни - какие 10 книг вы бы выбрали?
# * Определите цель на год (например, 25 или 100 книг).
# * Установите ежедневный минимальный объем чтения (начать с 20 страниц в день).
# * Запланируйте время для чтения в своем ежедневнике.
#
# **Дополнительные советы:**
#
# * Работа в книжном издательстве предоставляет много возможностей для чтения и доступа к библиотеке.
# * Замените другие занятия чтением (телевизор, интернет, соцсети).
# * Читайте рассказы - они отнимают меньше времени.
# * Не делайте перерывов между книгами: начните новую книгу в тот же день, когда закончили предыдущую.
#
# **Список книг для вдохновения и расширения кругозора:**
#
# * **Отсутствует в тексте.**

# %%
# %%time
query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 2000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 93.8 ms
# Wall time: 34.6 s

# %%
print(s[0])
# Out:
# ## Ключевые пункты текста:
#
# **Преимущества чтения:**
#
# * Расширение знаний, понимания мира и эмоционального интеллекта.
# * Развитие критического мышления и формирования собственных мнений.
# * Получение удовольствия от эскапизма, развлечений и новых перспектив.
# * Нахождение вдохновения, мотивации и руководства в жизни.
#
# **Рекомендации по чтению:**
#
# *  Читать 15-30 минут ежедневно для достижения значительных результатов.
# *  Использовать аромамасла (апельсин, эвкалипт, гвоздика) для концентрации.
# *  Отнестись к книге как к мудрому учителю, читая с открытым умом и желанием учиться.
# *  Применить технику с метрономом для быстрого чтения без отвлечений.
#
# **Важно:**
#
# * Текст не содержит конкретного списка книг для расширения кругозора и поиска вдохновения.

# %%
# %%time
query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 4000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 109 ms
# Wall time: 22.2 s

# %%
print(s[0])
# Out:
# Here are the key points from the text, focusing on reading for personal growth and inspiration:
#
# * **Reading Benefits:** Reading expands knowledge, understanding, emotional intelligence, critical thinking, and helps form opinions. It also offers enjoyment, escape, and inspiration.
# * **Reading Goals:** Aim for 15-30 minutes of daily reading to potentially read numerous books per year.
# * **Habit Formation Tips:**  Be selective with books, optimize your reading environment, prioritize reading time, set goals, and find your preferred reading style.
# * **Active Reading:** Engage with the text by highlighting, taking notes, and reflecting on what you read for deeper understanding.
#
#
# The text emphasizes that reading is a valuable habit for personal growth and inspiration, offering practical advice on how to make it a regular part of life.

# %% [markdown]
# # Batch page chunks

# %%
def summarization(content):
    input_dict["topic"] = topic
    input_dict["page"] = content
    summary = summary_chain.invoke(input_dict)
    return summary

def page_summarization(page):
    page_chunks = page.get("paragraphs", None)
    
    chunks = combine_chunks([" ".join(chunk.split()) for chunk in page_chunks if len(chunk.split()) > 3], max_words=max_words)

    batch = []
    for chunk in chunks:
        input_dict["topic"] = topic
        input_dict["page"] = chunk
        batch.append(input_dict)

    chunks_summaries = summary_chain.batch(batch)
    
    # chunks_summaries = [summarization(chunk) for chunk in chunks]
    while len(chunks_summaries) > 1:
        chunks_summaries = [summarization(chunk) for chunk in combine_chunks(chunks_summaries, max_words=max_words)]
    return chunks_summaries[0]

def query_summarization(query_pages):
    query_pages = [eval(p) for p in query_pages]
    pages_summary = [page_summarization(page) for page in query_pages if page.get("paragraphs", None)]
    if len(pages_summary) > 1:
        summary = [summarization(chunk) for chunk in combine_chunks(pages_summary, max_words=max_words)]
        return summary
    return pages_summary[0]

# %%
# %%time
query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 1500
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 78.1 ms
# Wall time: 36.8 s

# %% [markdown]
# # Batch queries chunks

# %%
def query_summarization(query_pages):
    query_pages = [eval(p) for p in query_pages]
    num_iters = 0
    chunks_batch = []
    for page in query_pages:
        page_chunks = page.get("paragraphs", None)
        if page_chunks:
            chunks = [" ".join(chunk.split()) for chunk in page_chunks if len(chunk.split()) > 3]
            if len(chunks) == 0:
                continue
            chunks_batch.extend(chunks)
    while (len(chunks_batch) > 1) | (num_iters == 4):
        num_iters += 1
        chunks_batch = combine_chunks(chunks_batch, max_words=max_words)
        batch = []
        for chunk in chunks_batch:
            input_dict["topic"] = topic
            input_dict["page"] = chunk
            batch.append(input_dict)

        chunks_batch = summary_chain.batch(batch)
    return chunks_batch

# %%
# %%time
query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 2000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 15.6 ms
# Wall time: 9.31 s

# %%
s
# Out:
# 'This text appears to be a promotional piece for an English language learning program, possibly with some elements about the benefits of reading.  Here\'s a breakdown:\n\n**Key Points:**\n\n* **Emphasis on Reading:** The text highlights the importance of reading for personal development and knowledge acquisition. It encourages active reading techniques like making notes and asking questions.\n* **Reading Goals:** It suggests realistic reading goals, starting with 15-30 minutes daily and increasing to an hour if possible.  It also provides a rough estimate of how many books one could read in a year based on these timeframes.\n* **Strategies for Habit Formation:** The text mentions strategies for making reading a habit, though it doesn\'t elaborate on them.\n* **Call to Action:** There are multiple calls to action throughout the text, encouraging readers to contact the program for more information or to sign up.\n\n**Promotional Elements:**\n\n* **Testimonials/Benefits:** While not explicitly stated, the text implies that reading will make someone "educated, inspired, erudite, and ready for new adventures."\n* **Target Audience:** The text seems aimed at parents who want their children to read more and potentially adults looking to improve their English skills.\n* **Specific Programs/Services:**  The text mentions a program with various offerings like trial lessons, pricing information, and details about child-friendly accommodations.\n\n**Missing Information:**\n\n* **Program Details:** The text doesn\'t clearly explain what the specific program entails, its curriculum, or teaching methods.\n\n\nLet me know if you have any other questions about this text! \n'

# %%
# %%time

prompt = summarization_candidates[1]
summarization_prompt = get_summarization_prompt(prompt)
# llm = get_chat(model)
summary_chain = summarization_prompt | llm | StrOutputParser()

query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 2000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 15.6 ms
# Wall time: 8.6 s

# %%
print(s)
# Out:
# Текст, который ты предоставил, представляет собой фрагмент статьи о пользе чтения и о том, как развить эту привычку.  В нем рассказывается:
#
# * **О важности активного чтения:** делать пометки, выписывать цитаты и задавать себе вопросы помогает лучше усвоить информацию.
# * **О необходимости разнообразия в чтении:** не бояться пробовать новые авторов, жанры и темы.
# * **О времени, которое нужно уделять чтению:** даже 15-30 минут в день могут быть полезны, а час - позволит прочитать больше книг.
# * **О количестве книг, которые можно прочитать за год:**  в среднем это может быть от 12 до 30 книг, в зависимости от времени, которое человек уделяет чтению.
# * **О стратегиях для развития привычки чтения:** статья обещает дать конкретные советы по этому вопросу.
#
#
# В тексте также упоминаются темы:
#
# * Рейтинг лучших книг о финансовой грамотности по возрасту.
# *  Особенности изучения английского языка через чтение сказок в оригинале.
# * Причины, почему дети не любят читать и как это исправить.
#
#
#
# Текст написан в дружелюбном тоне и направлен на то, чтобы мотивировать читателя к чтению.

# %%
# %%time

prompt = summarization_candidates[2]
summarization_prompt = get_summarization_prompt(prompt)
# llm = get_chat(model)
summary_chain = summarization_prompt | llm | StrOutputParser()

query = "сколько книг читать в год для саморазвития"
pages = page_information[page_information["query"] == query].drop_duplicates()
max_words = 2000
s = query_summarization(pages.data.tolist())
# Out:
# CPU times: total: 0 ns
# Wall time: 9.18 s

# %%
print(s)
# Out:
# Чтение - это бесконечный процесс саморазвития. Не бойтесь знакомиться с новыми авторами, жанрами и темами. Помните, что самое главное – это наслаждаться процессом и открывать для себя неизведанные миры на страницах книг.
#
# Время, которое рекомендуется выделить на чтение, варьируется в зависимости от режима дня и занятости. Однако 15-30 минут в день уже станут приемлемым вариантом. Средняя скорость чтения взрослого человека составляет около 200-300 слов в минуту. За 15 минут он прочитает порядка 3 000-4 500 слов, что соответствует примерно 10-15 страницам. Таким образом, даже при ограниченном времени, можно прочитать определенное количество книг. Если делать акцент на чтение в свободное время, к примеру вечером перед сном, то выделите около часа на прочтение выбранного произведения. Это уже открывает возможности для освоения большего количества литературы.
#
# Одна книга, в среднем, содержит около 300-400 страниц. При условии, что человек читает 10 страниц в день, то за месяц он осилит 1 книгу. Это даст в итоге 12 книг в год. В случае, если удалось высвободить час времени на ежедневное чтение, число увеличивается до 30 книг в год.

# %%
get_models("../models")
# Out:
# ['saiga-llama-3-q8_0', 'suzume-llama-3-8b-Q8_0']

# %%
results = pd.DataFrame()
max_words = 2000

for model in get_models("../models")[1:]:
    print(model)
    llm = get_chat(model)
    input_dict = gemma2_tokens.copy() if "gemma" in model else llama3_tokens.copy()
    for candidate in summarization_candidates:
        summarization_prompt = get_summarization_prompt(candidate)
        summary_chain = summarization_prompt | llm | StrOutputParser()
        outputs = {}
        inputs = queries[queries["model"] == model].reset_index(drop=True)
        for num, row in tqdm.tqdm(inputs.iterrows(), total=40):
            
            for query in eval(row.queries):
                pages = page_information[page_information["query"] == query].drop_duplicates()
                summary = query_summarization(pages.data.tolist())
                if len(summary) == 1:
                    summary = summary[0]
                output = {
                    "summary": summary,
                    "query": query
                }
                for key in output.keys():
                    outputs[key] = outputs.get(key, []) + [output[key]]
        
        summarization_df = pd.DataFrame.from_dict(outputs)
        summarization_df['stage'] = "web_search" # bug
        summarization_df['prompt'] = summarization_candidates.index(candidate)
        summarization_df['model'] = model.split("/")[-1]
        results = pd.concat([results, summarization_df], axis=0)
        results.to_csv('./data/summarization_results.csv', index=False)
# Out:
# saiga-llama-3-q8_0
#  32%|█████████████████████████▋                                                     | 13/40 [39:24<1:21:51, 181.92s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[195], line 17
#      15 for query in eval(row.queries):
#      16     pages = page_information[page_information["query"] == query].drop_duplicates()
# ---> 17     summary = query_summarization(pages.data.tolist())
#      18     if len(summary) == 1:
#      19         summary = summary[0]
#
# Cell In[165], line 20, in query_summarization(query_pages)
#      17         input_dict["page"] = chunk
#      18         batch.append(input_dict)
# ---> 20     chunks_batch = summary_chain.batch(batch)
#      21 return chunks_batch
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\runnables\base.py:2644, in RunnableSequence.batch(self, inputs, config, return_exceptions, **kwargs)
#    2642     else:
#    2643         for i, step in enumerate(self.steps):
# -> 2644             inputs = step.batch(
#    2645                 inputs,
#    2646                 [
#    2647                     # each step a child run of the corresponding root run
#    2648                     patch_config(
#    2649                         config, callbacks=rm.get_child(f"seq:step:{i+1}")
#    2650                     )
#    2651                     for rm, config in zip(run_managers, configs)
#    2652                 ],
#    2653                 return_exceptions=return_exceptions,
#    2654                 **(kwargs if i == 0 else {}),
#    2655             )
#    2657 # finish the root runs
#    2658 except BaseException as e:
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\runnables\base.py:639, in Runnable.batch(self, inputs, config, return_exceptions, **kwargs)
#     637 # If there's only one input, don't bother with the executor
#     638 if len(inputs) == 1:
# --> 639     return cast(List[Output], [invoke(inputs[0], configs[0])])
#     641 with get_executor_for_config(configs[0]) as executor:
#     642     return cast(List[Output], list(executor.map(invoke, inputs, configs)))
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\runnables\base.py:635, in Runnable.batch.<locals>.invoke(input, config)
#     633         return e
#     634 else:
# --> 635     return self.invoke(input, config, **kwargs)
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\language_models\chat_models.py:248, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     237 def invoke(
#     238     self,
#     239     input: LanguageModelInput,
#    (...)
#     243     **kwargs: Any,
#     244 ) -> BaseMessage:
#     245     config = ensure_config(config)
#     246     return cast(
#     247         ChatGeneration,
# --> 248         self.generate_prompt(
#     249             [self._convert_input(input)],
#     250             stop=stop,
#     251             callbacks=config.get("callbacks"),
#     252             tags=config.get("tags"),
#     253             metadata=config.get("metadata"),
#     254             run_name=config.get("run_name"),
#     255             run_id=config.pop("run_id", None),
#     256             **kwargs,
#     257         ).generations[0][0],
#     258     ).message
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\language_models\chat_models.py:681, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     673 def generate_prompt(
#     674     self,
#     675     prompts: List[PromptValue],
#    (...)
#     678     **kwargs: Any,
#     679 ) -> LLMResult:
#     680     prompt_messages = [p.to_messages() for p in prompts]
# --> 681     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\language_models\chat_models.py:538, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     536         if run_managers:
#     537             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 538         raise e
#     539 flattened_outputs = [
#     540     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     541     for res in results
#     542 ]
#     543 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\language_models\chat_models.py:528, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     525 for i, m in enumerate(messages):
#     526     try:
#     527         results.append(
# --> 528             self._generate_with_cache(
#     529                 m,
#     530                 stop=stop,
#     531                 run_manager=run_managers[i] if run_managers else None,
#     532                 **kwargs,
#     533             )
#     534         )
#     535     except BaseException as e:
#     536         if run_managers:
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_core\language_models\chat_models.py:753, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     751 else:
#     752     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 753         result = self._generate(
#     754             messages, stop=stop, run_manager=run_manager, **kwargs
#     755         )
#     756     else:
#     757         result = self._generate(messages, stop=stop, **kwargs)
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_community\chat_models\ollama.py:286, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#     262 def _generate(
#     263     self,
#     264     messages: List[BaseMessage],
#    (...)
#     267     **kwargs: Any,
#     268 ) -> ChatResult:
#     269     """Call out to Ollama's generate endpoint.
#     270
#     271     Args:
#    (...)
#     283             ])
#     284     """
# --> 286     final_chunk = self._chat_stream_with_aggregation(
#     287         messages,
#     288         stop=stop,
#     289         run_manager=run_manager,
#     290         verbose=self.verbose,
#     291         **kwargs,
#     292     )
#     293     chat_generation = ChatGeneration(
#     294         message=AIMessage(content=final_chunk.text),
#     295         generation_info=final_chunk.generation_info,
#     296     )
#     297     return ChatResult(generations=[chat_generation])
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_community\chat_models\ollama.py:217, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     208 def _chat_stream_with_aggregation(
#     209     self,
#     210     messages: List[BaseMessage],
#    (...)
#     214     **kwargs: Any,
#     215 ) -> ChatGenerationChunk:
#     216     final_chunk: Optional[ChatGenerationChunk] = None
# --> 217     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#     218         if stream_resp:
#     219             chunk = _chat_stream_response_to_chat_generation_chunk(stream_resp)
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\langchain_community\chat_models\ollama.py:189, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     179 def _create_chat_stream(
#     180     self,
#     181     messages: List[BaseMessage],
#     182     stop: Optional[List[str]] = None,
#     183     **kwargs: Any,
#     184 ) -> Iterator[str]:
#     185     payload = {
#     186         "model": self.model,
#     187         "messages": self._convert_messages_to_ollama_messages(messages),
#     188     }
# --> 189     yield from self._create_stream(
#     190         payload=payload, stop=stop, api_url=f"{self.base_url}/api/chat", **kwargs
#     191     )
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\requests\models.py:869, in Response.iter_lines(self, chunk_size, decode_unicode, delimiter)
#     860 """Iterates over the response data, one line at a time.  When
#     861 stream=True is set on the request, this avoids reading the
#     862 content at once into memory for large responses.
#     863
#     864 .. note:: This method is not reentrant safe.
#     865 """
#     867 pending = None
# --> 869 for chunk in self.iter_content(
#     870     chunk_size=chunk_size, decode_unicode=decode_unicode
#     871 ):
#     872     if pending is not None:
#     873         chunk = pending + chunk
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\requests\utils.py:572, in stream_decode_response_unicode(iterator, r)
#     569     return
#     571 decoder = codecs.getincrementaldecoder(r.encoding)(errors="replace")
# --> 572 for chunk in iterator:
#     573     rv = decoder.decode(chunk)
#     574     if rv:
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\urllib3\response.py:1206, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1203     amt = None
#    1205 while True:
# -> 1206     self._update_chunk_length()
#    1207     if self.chunk_left == 0:
#    1208         break
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\site-packages\urllib3\response.py:1125, in HTTPResponse._update_chunk_length(self)
#    1123 if self.chunk_left is not None:
#    1124     return None
# -> 1125 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1126 line = line.split(b";", 1)[0]
#    1127 try:
#
# File D:\programs\miniconda3\envs\llm_eval\Lib\socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# Модели архитектуры llama3 не справляется с длинной контекста и начинают генерировать много текста. Работает только до 1 000 слов, но тогда теряется часть смысла и увеличивается компьют. Пайплайн не успеет отработать за менее 1 минуты

# %%
results = pd.read_csv('./data/summarization_results.csv')

# %%
results["word_count"] = results["summary"].apply(lambda x: len(x.split()) if isinstance(x, str) else len(x))

# %%
results
# Out:
#                                                summary  \
# 0    ## Ключевые факты и данные:\n\n* **Расширение ...
# 1    ## Ключевые факты и данные:\n\n**Скорочтение:*...
# 2    ## Ключевые факты и данные из текста:\n\n**Чте...
# 3    Текст отлично структурирован и содержит много ...
# 4                                                   []
# ..                                                 ...
# 235  - Писатель Айодеджи Авосика.\n- Стивен Кови.\n...
# 236  - 179 человек в Великобритании заразились виру...
# 237  - Для путешествий в горы необходимы знания и у...
# 238     Пожалуйста, предоставьте текст для анализа. \n
# 239  -  Новые друзья: люди, которые разделяют ваши ...
#
#                                                  query       stage  prompt  \
# 0         книги для расширения кругозора и вдохновения  web_search       0
# 1    топ 5-7 книг для саморазвития и поиска вдохнов...  web_search       0
# 2           сколько книг читать в год для саморазвития  web_search       0
# 3    как развить привычку читать и выбрать интересн...  web_search       0
# 4          топ 5 упражнений для утренней зарядки видео  web_search       0
# ..                                                 ...         ...     ...
# 235                как улучшить коммуникативные навыки  web_search       2
# 236                    как путешествия меняют человека  web_search       2
# 237     влияние путешествий на личность и саморазвитие  web_search       2
# 238        практические методы развития самодисциплины  web_search       2
# 239  советы по повышению самодисциплины для достиже...  web_search       2
#
#                     model  word_count
# 0    gemma-2-9b-it-Q8_0_L          88
# 1    gemma-2-9b-it-Q8_0_L         104
# 2    gemma-2-9b-it-Q8_0_L         128
# 3    gemma-2-9b-it-Q8_0_L         154
# 4    gemma-2-9b-it-Q8_0_L           1
# ..                    ...         ...
# 235  gemma-2-9b-it-Q8_0_L          11
# 236  gemma-2-9b-it-Q8_0_L          19
# 237  gemma-2-9b-it-Q8_0_L          61
# 238  gemma-2-9b-it-Q8_0_L           5
# 239  gemma-2-9b-it-Q8_0_L          41
#
# [240 rows x 6 columns]

# %%
results.set_index(['prompt', 'model']).groupby(level=['prompt', 'model'])[
    ["word_count"]].mean()
# Out:
#                              word_count
# prompt model
# 0      gemma-2-9b-it-Q8_0_L    132.1875
# 1      gemma-2-9b-it-Q8_0_L    135.8750
# 2      gemma-2-9b-it-Q8_0_L     76.6500

# %%
results[results["word_count"] < 20]
# Out:
#                                                summary  \
# 4                                                   []
# 16                                                  []
# 21   Пожалуйста, предоставьте текст, из которого ну...
# 24                                                  []
# 31   Извини, но я не понимаю, что ты спрашиваешь. П...
# 38                                                  []
# 84                                                  []
# 96                                                  []
# 104                                                 []
# 111  Извини, но я не понимаю, что ты спрашиваешь. П...
# 118                                                 []
# 164                                                 []
# 172  Данные, которые используются для обучения ИИ, ...
# 176                                                 []
# 180  Социальные сети оказывают значительное влияние...
# 184                                                 []
# 190  Привет!  \n\nЯ могу помочь тебе с переводом, н...
# 191  Я не понимаю, что вы просите. Пожалуйста, пере...
# 194                    Музыка, танцы, письмо, театр \n
# 198                                                 []
# 211  - 2004 год\n- HR-Portal\n- Сообщество HR-Менед...
# 218  ##  Краткое описание задачи: \n\n\n**В какие с...
# 235  - Писатель Айодеджи Авосика.\n- Стивен Кови.\n...
# 236  - 179 человек в Великобритании заразились виру...
# 238     Пожалуйста, предоставьте текст для анализа. \n
#
#                                                  query       stage  prompt  \
# 4          топ 5 упражнений для утренней зарядки видео  web_search       0
# 16   кейсы применения big data для оптимизации бизн...  web_search       0
# 21          #ОбщественноеМнение #СоциальныеСети #Медиа  web_search       0
# 24   методы развития критического мышления с упражн...  web_search       0
# 31   методы повышения продуктивности и организованн...  web_search       0
# 38                 как составить бюджет для начинающих  web_search       0
# 84         топ 5 упражнений для утренней зарядки видео  web_search       1
# 96   кейсы применения big data для оптимизации бизн...  web_search       1
# 104  методы развития критического мышления с упражн...  web_search       1
# 111  методы повышения продуктивности и организованн...  web_search       1
# 118                как составить бюджет для начинающих  web_search       1
# 164        топ 5 упражнений для утренней зарядки видео  web_search       2
# 172  как искусственный интеллект изменит политику в...  web_search       2
# 176  кейсы применения big data для оптимизации бизн...  web_search       2
# 180  Влияние социальных сетей на формирование общес...  web_search       2
# 184  методы развития критического мышления с упражн...  web_search       2
# 190  практические советы по организации рабочего вр...  web_search       2
# 191  методы повышения продуктивности и организованн...  web_search       2
# 194            методы развития творческих способностей  web_search       2
# 198                как составить бюджет для начинающих  web_search       2
# 211      Практические упражнения для повышения эмпатии  web_search       2
# 218                       методы развития креативности  web_search       2
# 235                как улучшить коммуникативные навыки  web_search       2
# 236                    как путешествия меняют человека  web_search       2
# 238        практические методы развития самодисциплины  web_search       2
#
#                     model  word_count
# 4    gemma-2-9b-it-Q8_0_L           1
# 16   gemma-2-9b-it-Q8_0_L           1
# 21   gemma-2-9b-it-Q8_0_L          17
# 24   gemma-2-9b-it-Q8_0_L           1
# 31   gemma-2-9b-it-Q8_0_L          15
# 38   gemma-2-9b-it-Q8_0_L           1
# 84   gemma-2-9b-it-Q8_0_L           1
# 96   gemma-2-9b-it-Q8_0_L           1
# 104  gemma-2-9b-it-Q8_0_L           1
# 111  gemma-2-9b-it-Q8_0_L          15
# 118  gemma-2-9b-it-Q8_0_L           1
# 164  gemma-2-9b-it-Q8_0_L           1
# 172  gemma-2-9b-it-Q8_0_L          14
# 176  gemma-2-9b-it-Q8_0_L           1
# 180  gemma-2-9b-it-Q8_0_L          17
# 184  gemma-2-9b-it-Q8_0_L           1
# 190  gemma-2-9b-it-Q8_0_L          17
# 191  gemma-2-9b-it-Q8_0_L          10
# 194  gemma-2-9b-it-Q8_0_L           4
# 198  gemma-2-9b-it-Q8_0_L           1
# 211  gemma-2-9b-it-Q8_0_L           8
# 218  gemma-2-9b-it-Q8_0_L          11
# 235  gemma-2-9b-it-Q8_0_L          11
# 236  gemma-2-9b-it-Q8_0_L          19
# 238  gemma-2-9b-it-Q8_0_L           5

# %%
queries.queries.iloc[0]
# Out:
# "['книги для расширения кругозора и вдохновения', 'топ 5-7 книг для саморазвития и поиска вдохновения']"

# %%
for sample in results[results["query"] == 'книги для расширения кругозора и вдохновения'].summary.tolist():
    print(sample)
    print("=============")
# Out:
# ## Ключевые факты и данные:
#
# * **Расширение тематики МИФ:**  Книги о путешествиях, кулинарии, саморазвитии, отношениях и языках стали популярны помимо бизнес-литературы.
# * **Популярность научпопа:**
#     * Книги о науке и математике обрели широкую аудиторию после успеха "Удовольствия от Х".
#     * "Голая статистика" стала хитом, признанным Афишей лучшим научпопом лета.
#     * Исследовательские книги об отношениях ("Размножение в неволе", "Как хочет женщина") вошли в топы продаж.
# * **Будущее за научпопом:**  Авторы считают, что научно-популярная литература имеет большое будущее.
# * **Бесплатная книга:** До 17 июля можно скачать книгу "Мозг во сне" бесплатно.
#
#
#
# =============
# Вот ключевые факты и данные из текста:
#
# * **2015 год:** Вышла книга "Удовольствие от Х", которая показала популярность книг о науке и математике.
# * **"Голая статистика":** Научпоп-книга, признанная Афишей лучшим изданием лета.
# * **"Размножение в неволе" и "Как хочет женщина":**  Исследовательские книги об отношениях, которые стали популярными.
# * **До 17 июля:** Бесплатная книга "Мозг во сне" доступна для скачивания.
#
#
#
# =============
# - 2015 год
# - "Удовольствие от Х"
# - "Голая статистика"
# - Афиша
# - "Размножение в неволе"
# - "Как хочет женщина"
# - "Красота в квадрате"
# - "Мозг во сне"
# - 17 июля
#
#
#
# =============

# %%
for sample in results[results["query"] == 'топ 5-7 книг для саморазвития и поиска вдохновения'].summary.tolist():
    print(sample)
    print("=============")
# Out:
# ## Ключевые факты и данные:
#
# **Скорочтение:**
#
# *  Развивает память, мышление, внимательность.
# *  Позволяет быстрее читать, понимать и запоминать текст.
# *  Применяется в учебе, работе, подготовке к встречам/презентациям.
# *  Тренировка индивидуальна, с учетом уровня развития каждого ученика.
#
# **Обучение скорочтению:**
#
# *  В Академии Skills предлагают занятия для детей с 4 лет и взрослых.
# *  Есть бесплатный пробный урок.
# *  Методика основана на многолетнем опыте и учитывает эмоциональное состояние ребенка.
#
# **Книги:**
#
# *  Не являются основным инструментом обучения скорочтению, но могут служить дополнительной поддержкой и мотивацией.
#
#
# **Детская одаренность:**
#
# *  Книга посвящена диагностике и развитию детской одаренности в современной образовательной среде.
# *  Направлена на педагогов, психологов, студентов педагогических вузов.
#
#
#
#
# =============
# ## Ключевые факты и данные:
#
# **Скорочтение:**
#
# * Методика скорочтения сокращает время чтения в 10 раз.
# * Индивидуальный подход к обучению, программа подбирается для каждого ученика.
# * Занятия должны быть регулярными.
# * Педагог оценивает успехи и корректирует программу обучения.
#
# **Академия Skills:**
#
# * Начинают обучение с 4 лет.
# * Готовят к школе.
# * Предлагают бесплатный пробный урок.
#
# **Книга о детской одаренности:**
#
# * Адресована педагогам, психологам и студентам высших учебных заведений.
# * Соответствует стандартам подготовки педагогов и практических психологов.
# * Охватывает вопросы психологии детской одаренности, развития и обучения одаренных детей.
#
#
# **Список книг для расширения кругозора и поиска вдохновения:**
#
# * В тексте не представлен список книг.
#
#
#
#
# =============
# - Скорочтение помогает развить память, мышление и внимательность.
# - Методика скорочтения сокращает время чтения в 10 раз.
# - Для каждого ученика составляется индивидуальная программа обучения.
# - Занятия по скорочтению проводятся для детей с 4 лет.
# - Академия Skills предлагает бесплатный пробный урок.
# - Книга посвящена проблемам диагностики и развития детской одаренности.
# - Издание адресовано педагогам, психологам и студентам высших учебных заведений.
#
#
#
# =============
